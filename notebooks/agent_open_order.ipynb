# %% [markdown]
# # Agent open order
# This notebook focuses on the first-entry contract for agent workflows.

# %%
from tsdataforge import demo
bundle = demo(output_dir='macro_bundle', scenario='macro_public')
bundle.index.to_min_dict()

# %%
bundle.index.to_action_plan_dict()
