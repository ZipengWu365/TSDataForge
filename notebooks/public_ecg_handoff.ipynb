# %% [markdown]
# # Public ECG handoff
# This notebook shows the shortest real public demo path in TSDataForge.

# %%
from tsdataforge import demo
bundle = demo(output_dir='ecg_bundle', scenario='ecg_public')
bundle.output_dir

# %%
bundle.index.to_min_dict()
